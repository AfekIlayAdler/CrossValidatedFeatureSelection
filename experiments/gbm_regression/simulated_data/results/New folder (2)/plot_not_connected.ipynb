# %% [raw]
# def get_x_y():
#     X = DataFrame()
#     nrows = 10 ** 4
#     y = Series(zeros(nrows))
#     for i in range(5, 10):
#         X[str(i)] = random.randint(0, 2 ** i, nrows)
#         X[str(i)] = X[str(i)].astype('category')
#         # y += X[str(i)].isin(list(range(2 ** i - 1))) * 1
#
#     X['numeric'] = random.random(nrows)*1
#     y += random.random(nrows)*1
#     # y += Series(y)
#     # X.columns = [str(i) for i in X.columns]
#     # y = Series(random.random(nrows))
#     return X, y

# %%
import sys
sys.path.append(r"C:\Users\afeki\Desktop\code\CrossValidatedFeatureSelection\experiments")  # path contains python_file.py
from plot_utils import get_regular_paths, get_feature_importance, plot_fi, plot_metrics

# %%
is_classification = False
metrics = ['ntrees', 'nleaves', 'error']
if is_classification:
    metrics += ['logloss']
paths = get_regular_paths(one_hot=False)
for model, model_path in paths.items():
    try:
        model_fi = get_feature_importance(model, model_path)
        plot_fi(model, model_fi)
    except:
        pass
for metric in metrics:
    plot_metrics(paths, metric)
# Out:
# C:\Users\afeki\Desktop\code\CrossValidatedFeatureSelection\experiments\plot_utils.py:73: UserWarning: catboost\catboost_vanilla_3.yaml feature importance permutation_test is nan
#   warnings.warn(message)
# C:\Users\afeki\Desktop\code\CrossValidatedFeatureSelection\experiments\plot_utils.py:73: UserWarning: ours_vanilla\ours_vanilla___10.yaml feature importance permutation_test is nan
#   warnings.warn(message)
# C:\Users\afeki\Desktop\code\CrossValidatedFeatureSelection\experiments\plot_utils.py:73: UserWarning: ours_vanilla\ours_vanilla___12.yaml feature importance permutation_test is nan
#   warnings.warn(message)
# C:\Users\afeki\Desktop\code\CrossValidatedFeatureSelection\experiments\plot_utils.py:73: UserWarning: ours_vanilla\ours_vanilla___16.yaml feature importance permutation_test is nan
#   warnings.warn(message)
# C:\Users\afeki\Desktop\code\CrossValidatedFeatureSelection\experiments\plot_utils.py:73: UserWarning: ours_vanilla\ours_vanilla___18.yaml feature importance permutation_test is nan
#   warnings.warn(message)
# C:\Users\afeki\Desktop\code\CrossValidatedFeatureSelection\experiments\plot_utils.py:73: UserWarning: ours_vanilla\ours_vanilla___21.yaml feature importance permutation_test is nan
#   warnings.warn(message)
# C:\Users\afeki\Desktop\code\CrossValidatedFeatureSelection\experiments\plot_utils.py:73: UserWarning: ours_vanilla\ours_vanilla___23.yaml feature importance permutation_test is nan
#   warnings.warn(message)
# C:\Users\afeki\Desktop\code\CrossValidatedFeatureSelection\experiments\plot_utils.py:73: UserWarning: ours_vanilla\ours_vanilla___24.yaml feature importance permutation_test is nan
#   warnings.warn(message)
# C:\Users\afeki\Desktop\code\CrossValidatedFeatureSelection\experiments\plot_utils.py:73: UserWarning: ours_vanilla\ours_vanilla___25.yaml feature importance permutation_test is nan
#   warnings.warn(message)
# C:\Users\afeki\Desktop\code\CrossValidatedFeatureSelection\experiments\plot_utils.py:73: UserWarning: ours_vanilla\ours_vanilla___4.yaml feature importance permutation_test is nan
#   warnings.warn(message)
# C:\Users\afeki\Desktop\code\CrossValidatedFeatureSelection\experiments\plot_utils.py:73: UserWarning: sklearn\sklearn_mean_imputing_2.yaml feature importance permutation_test is nan
#   warnings.warn(message)
# C:\Users\afeki\Desktop\code\CrossValidatedFeatureSelection\experiments\plot_utils.py:73: UserWarning: sklearn\sklearn_mean_imputing_20.yaml feature importance permutation_test is nan
#   warnings.warn(message)
# C:\Users\afeki\Desktop\code\CrossValidatedFeatureSelection\experiments\plot_utils.py:73: UserWarning: sklearn\sklearn_mean_imputing_7.yaml feature importance permutation_test is nan
#   warnings.warn(message)
# C:\Users\afeki\Desktop\code\CrossValidatedFeatureSelection\experiments\plot_utils.py:73: UserWarning: xgboost\xgboost_mean_imputing_1.yaml feature importance permutation_test is nan
#   warnings.warn(message)
# C:\Users\afeki\Desktop\code\CrossValidatedFeatureSelection\experiments\plot_utils.py:73: UserWarning: xgboost\xgboost_mean_imputing_5.yaml feature importance permutation_test is nan
#   warnings.warn(message)
# C:\Users\afeki\Desktop\code\CrossValidatedFeatureSelection\experiments\plot_utils.py:73: UserWarning: xgboost\xgboost_mean_imputing_6.yaml feature importance permutation_test is nan
#   warnings.warn(message)
