# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

import seaborn as sns
# %matplotlib inline
from ast import literal_eval
from glob import glob

# %%
paths = {
    'Lgbm' :"lgbm/lgbm_vanilla",
    'Catboost' :"catboost/catboost_vanilla",
    "Ours_kfold" :"ours/ours_Kfold",
     "Ours_Vanilla" :"ours/ours_CartVanilla",
    "Sklearn_Mean_Imputing" : "sklearn/sklearn_mean_imputing",
    "Sklearn_One_Hot" : "sklearn/sklearn_one_hot",
    'Xgboost_Mean_Imputing': "xgboost/xgboost_mean_imputing",
    'Xgboost_One_Hot': "xgboost/xgboost_one_hot"
    
    
}

# %%
features = ['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp', 'atemp', 'humidity', 'windspeed']
all_cols = [ 'gain', 'permutation_train', 'permutation_test','shap_train', 'shap_test']
our_cols = [ 'gain', 'permutation_train', 'permutation_test']
temp_paths = glob("lgbm/lgbm_vanilla*")

# %%
def plot_boxplot(paths, algorithm, results):
    temp_results = []
    cols = our_cols if algorithm.startswith('Ours') else all_cols
    for path in paths:
        df = pd.read_csv(path, converters = {col: literal_eval for col in cols})
        for fi in all_cols:
            temp_df = pd.Series(df.loc[0,fi]).to_frame() 
            temp_df = temp_df.reset_index()
            temp_df.columns = ['feature', 'value']
            temp_df['fi_type'] = fi
            temp_df['algo'] = algorithm
            temp_results.append(temp_df)

    plt.figure(figsize=(20,8))
    temp_results = pd.concat(temp_results)
    temp_results = temp_results[temp_results['feature'] != 0]
    results.append(temp_results)
    sns.violinplot(data = temp_results, x = 'feature', y = 'value', hue = 'fi_type').set_title(algorithm)
    plt.show()

# %%
results = []
for algo, path in paths.items():
    plot_boxplot(glob(path +"*"), algo, results)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in fit_kde(self, x, bw)
#     713         try:
# --> 714             kde = stats.gaussian_kde(x, bw)
#     715         except TypeError:
#
# ~\anaconda3\lib\site-packages\scipy\stats\kde.py in __init__(self, dataset, bw_method, weights)
#     208
# --> 209         self.set_bandwidth(bw_method=bw_method)
#     210
#
# ~\anaconda3\lib\site-packages\scipy\stats\kde.py in set_bandwidth(self, bw_method)
#     564
# --> 565         self._compute_covariance()
#     566
#
# ~\anaconda3\lib\site-packages\scipy\stats\kde.py in _compute_covariance(self)
#     575                                                bias=False,
# --> 576                                                aweights=self.weights))
#     577             self._data_inv_cov = linalg.inv(self._data_covariance)
#
# <__array_function__ internals> in cov(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\function_base.py in cov(m, y, rowvar, bias, ddof, fweights, aweights)
#    2430
# -> 2431     avg, w_sum = average(X, axis=1, weights=w, returned=True)
#    2432     w_sum = w_sum[0]
#
# <__array_function__ internals> in average(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\function_base.py in average(a, axis, weights, returned)
#     419
# --> 420         scl = wgt.sum(axis=axis, dtype=result_dtype)
#     421         if np.any(scl == 0.0):
#
# ~\anaconda3\lib\site-packages\numpy\core\_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      37          initial=_NoValue, where=True):
# ---> 38     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      39
#
# TypeError: No loop matching the specified signature and casting was found for ufunc add
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-be69cd131617> in <module>
#       1 results = []
#       2 for algo, path in paths.items():
# ----> 3     plot_boxplot(glob(path +"*"), algo, results)
#
# <ipython-input-55-05c434e13825> in plot_boxplot(paths, algorithm, results)
#      16     temp_results = temp_results[temp_results['feature'] != 0]
#      17     results.append(temp_results)
# ---> 18     sns.violinplot(data = temp_results, x = 'feature', y = 'value', hue = 'fi_type').set_title(algorithm)
#      19     plt.show()
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in violinplot(x, y, hue, data, order, hue_order, bw, cut, scale, scale_hue, gridsize, width, inner, split, dodge, orient, linewidth, color, palette, saturation, ax, **kwargs)
#    2391                              bw, cut, scale, scale_hue, gridsize,
#    2392                              width, inner, split, dodge, orient, linewidth,
# -> 2393                              color, palette, saturation)
#    2394
#    2395     if ax is None:
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, bw, cut, scale, scale_hue, gridsize, width, inner, split, dodge, orient, linewidth, color, palette, saturation)
#     559         self.establish_variables(x, y, hue, data, orient, order, hue_order)
#     560         self.establish_colors(color, palette, saturation)
# --> 561         self.estimate_densities(bw, cut, scale, scale_hue, gridsize)
#     562
#     563         self.gridsize = gridsize
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in estimate_densities(self, bw, cut, scale, scale_hue, gridsize)
#     674
#     675                     # Fit the KDE and get the used bandwidth size
# --> 676                     kde, bw_used = self.fit_kde(kde_data, bw)
#     677
#     678                     # Determine the support grid and get the density over it
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in fit_kde(self, x, bw)
#     714             kde = stats.gaussian_kde(x, bw)
#     715         except TypeError:
# --> 716             kde = stats.gaussian_kde(x)
#     717             if bw != "scott":  # scipy default
#     718                 msg = ("Ignoring bandwidth choice, "
#
# ~\anaconda3\lib\site-packages\scipy\stats\kde.py in __init__(self, dataset, bw_method, weights)
#     207             self._neff = 1/sum(self._weights**2)
#     208
# --> 209         self.set_bandwidth(bw_method=bw_method)
#     210
#     211     def evaluate(self, points):
#
# ~\anaconda3\lib\site-packages\scipy\stats\kde.py in set_bandwidth(self, bw_method)
#     563             raise ValueError(msg)
#     564
# --> 565         self._compute_covariance()
#     566
#     567     def _compute_covariance(self):
#
# ~\anaconda3\lib\site-packages\scipy\stats\kde.py in _compute_covariance(self)
#     574             self._data_covariance = atleast_2d(cov(self.dataset, rowvar=1,
#     575                                                bias=False,
# --> 576                                                aweights=self.weights))
#     577             self._data_inv_cov = linalg.inv(self._data_covariance)
#     578
#
# <__array_function__ internals> in cov(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\function_base.py in cov(m, y, rowvar, bias, ddof, fweights, aweights)
#    2429             w *= aweights
#    2430
# -> 2431     avg, w_sum = average(X, axis=1, weights=w, returned=True)
#    2432     w_sum = w_sum[0]
#    2433
#
# <__array_function__ internals> in average(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\function_base.py in average(a, axis, weights, returned)
#     418             wgt = wgt.swapaxes(-1, axis)
#     419
# --> 420         scl = wgt.sum(axis=axis, dtype=result_dtype)
#     421         if np.any(scl == 0.0):
#     422             raise ZeroDivisionError(
#
# ~\anaconda3\lib\site-packages\numpy\core\_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      36 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      37          initial=_NoValue, where=True):
# ---> 38     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      39
#      40 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#
# TypeError: No loop matching the specified signature and casting was found for ufunc add

# %%
results = pd.concat(results)

# %%
df = results.groupby(['fi_type', 'algo','feature']).value.apply(np.std).to_frame().reset_index()
for fi in df.fi_type.unique():
    print(fi)
    display(df[df.fi_type == fi].pivot(index = 'algo', columns = 'feature',values = 'value' ).style.background_gradient() )
# df['value'].apply(np.std)
# Out:
# gain
# <style  type="text/css" >
#     #T_631f23a8_980f_11ea_8191_9c305b77d51erow0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow0_col1 {
#             background-color:  #2383ba;
#             color:  #000000;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow0_col2 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow0_col3 {
#             background-color:  #2081b9;
#             color:  #000000;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow0_col4 {
#             background-color:  #7dacd1;
#             color:  #000000;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow0_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow0_col6 {
#             background-color:  #ced0e6;
#             color:  #000000;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow0_col7 {
#             background-color:  #b1c2de;
#             color:  #000000;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow0_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow1_col0 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow1_col1 {
#             background-color:  #e0dded;
#             color:  #000000;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow1_col2 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow1_col3 {
#             background-color:  #3790c0;
#             color:  #000000;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow1_col4 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow1_col5 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow1_col6 {
#             background-color:  #adc1dd;
#             color:  #000000;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow1_col7 {
#             background-color:  #c6cce3;
#             color:  #000000;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow1_col8 {
#             background-color:  #84b0d3;
#             color:  #000000;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow2_col0 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow2_col1 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow2_col2 {
#             background-color:  #ede7f2;
#             color:  #000000;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow2_col3 {
#             background-color:  #76aad0;
#             color:  #000000;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow2_col4 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow2_col5 {
#             background-color:  #b7c5df;
#             color:  #000000;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow2_col6 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow2_col7 {
#             background-color:  #c2cbe2;
#             color:  #000000;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow2_col8 {
#             background-color:  #b1c2de;
#             color:  #000000;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow3_col0 {
#             background-color:  #acc0dd;
#             color:  #000000;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow3_col1 {
#             background-color:  #3991c1;
#             color:  #000000;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow3_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow3_col3 {
#             background-color:  #dad9ea;
#             color:  #000000;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow3_col4 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow3_col5 {
#             background-color:  #8eb3d5;
#             color:  #000000;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow3_col6 {
#             background-color:  #e6e2ef;
#             color:  #000000;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow3_col7 {
#             background-color:  #cacee5;
#             color:  #000000;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow3_col8 {
#             background-color:  #05659f;
#             color:  #f1f1f1;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow4_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow4_col1 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow4_col2 {
#             background-color:  #f4edf6;
#             color:  #000000;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow4_col3 {
#             background-color:  #dedcec;
#             color:  #000000;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow4_col4 {
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow4_col5 {
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow4_col6 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow4_col7 {
#             background-color:  #d3d4e7;
#             color:  #000000;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow4_col8 {
#             background-color:  #a5bddb;
#             color:  #000000;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow5_col0 {
#             background-color:  #c2cbe2;
#             color:  #000000;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow5_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow5_col2 {
#             background-color:  #f4edf6;
#             color:  #000000;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow5_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow5_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow5_col5 {
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow5_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow5_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow5_col8 {
#             background-color:  #a9bfdc;
#             color:  #000000;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow6_col0 {
#             background-color:  #04639b;
#             color:  #f1f1f1;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow6_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow6_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow6_col3 {
#             background-color:  #046299;
#             color:  #f1f1f1;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow6_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_631f23a8_980f_11ea_8191_9c305b77d51erow6_col5 {
#             background-color:  #94b6d7;
#             color:  #000000;
# permutation_test
# <style  type="text/css" >
#     #T_63252e4c_980f_11ea_b995_9c305b77d51erow0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow0_col1 {
#             background-color:  #d2d3e7;
#             color:  #000000;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow0_col2 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow0_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow0_col5 {
#             background-color:  #8eb3d5;
#             color:  #000000;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow0_col6 {
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow0_col7 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow0_col8 {
#             background-color:  #97b7d7;
#             color:  #000000;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow1_col0 {
#             background-color:  #a4bcda;
#             color:  #000000;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow1_col2 {
#             background-color:  #e2dfee;
#             color:  #000000;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow1_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow1_col4 {
#             background-color:  #1379b5;
#             color:  #f1f1f1;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow1_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow1_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow1_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow1_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow2_col0 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow2_col1 {
#             background-color:  #b5c4df;
#             color:  #000000;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow2_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow2_col3 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow2_col4 {
#             background-color:  #b1c2de;
#             color:  #000000;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow2_col5 {
#             background-color:  #b3c3de;
#             color:  #000000;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow2_col6 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow2_col7 {
#             background-color:  #c9cee4;
#             color:  #000000;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow2_col8 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow3_col0 {
#             background-color:  #67a4cc;
#             color:  #000000;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow3_col1 {
#             background-color:  #2685bb;
#             color:  #000000;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow3_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow3_col3 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow3_col4 {
#             background-color:  #80aed2;
#             color:  #000000;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow3_col5 {
#             background-color:  #bbc7e0;
#             color:  #000000;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow3_col6 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow3_col7 {
#             background-color:  #b9c6e0;
#             color:  #000000;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow3_col8 {
#             background-color:  #81aed2;
#             color:  #000000;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow4_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow4_col1 {
#             background-color:  #b8c6e0;
#             color:  #000000;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow4_col2 {
#             background-color:  #549cc7;
#             color:  #000000;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow4_col3 {
#             background-color:  #d3d4e7;
#             color:  #000000;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow4_col4 {
#             background-color:  #2d8abd;
#             color:  #000000;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow4_col5 {
#             background-color:  #e2dfee;
#             color:  #000000;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow4_col6 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow4_col7 {
#             background-color:  #63a2cb;
#             color:  #000000;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow4_col8 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow5_col0 {
#             background-color:  #86b0d3;
#             color:  #000000;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow5_col1 {
#             background-color:  #b5c4df;
#             color:  #000000;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow5_col2 {
#             background-color:  #056aa6;
#             color:  #f1f1f1;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow5_col3 {
#             background-color:  #6da6cd;
#             color:  #000000;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow5_col4 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow5_col5 {
#             background-color:  #cccfe5;
#             color:  #000000;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow5_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow5_col7 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow5_col8 {
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow6_col0 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow6_col1 {
#             background-color:  #b3c3de;
#             color:  #000000;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow6_col2 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow6_col3 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow6_col4 {
#             background-color:  #e0dded;
#             color:  #000000;
#         }    #T_63252e4c_980f_11ea_b995_9c305b77d51erow6_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
# permutation_train
# <style  type="text/css" >
#     #T_632b4f10_980f_11ea_a399_9c305b77d51erow0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow0_col1 {
#             background-color:  #8fb4d6;
#             color:  #000000;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow0_col2 {
#             background-color:  #69a5cc;
#             color:  #000000;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow0_col3 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow0_col5 {
#             background-color:  #1e80b8;
#             color:  #000000;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow0_col6 {
#             background-color:  #d1d2e6;
#             color:  #000000;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow0_col7 {
#             background-color:  #96b6d7;
#             color:  #000000;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow0_col8 {
#             background-color:  #046097;
#             color:  #f1f1f1;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow1_col0 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow1_col2 {
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow1_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow1_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow1_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow1_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow1_col7 {
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow1_col8 {
#             background-color:  #0568a3;
#             color:  #f1f1f1;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow2_col0 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow2_col1 {
#             background-color:  #b1c2de;
#             color:  #000000;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow2_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow2_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow2_col4 {
#             background-color:  #91b5d6;
#             color:  #000000;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow2_col5 {
#             background-color:  #80aed2;
#             color:  #000000;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow2_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow2_col7 {
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow2_col8 {
#             background-color:  #6fa7ce;
#             color:  #000000;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow3_col0 {
#             background-color:  #62a2cb;
#             color:  #000000;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow3_col1 {
#             background-color:  #5ea0ca;
#             color:  #000000;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow3_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow3_col3 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow3_col4 {
#             background-color:  #7bacd1;
#             color:  #000000;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow3_col5 {
#             background-color:  #569dc8;
#             color:  #000000;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow3_col6 {
#             background-color:  #eee9f3;
#             color:  #000000;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow3_col7 {
#             background-color:  #a9bfdc;
#             color:  #000000;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow3_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow4_col0 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow4_col1 {
#             background-color:  #eee9f3;
#             color:  #000000;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow4_col2 {
#             background-color:  #034267;
#             color:  #f1f1f1;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow4_col3 {
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow4_col4 {
#             background-color:  #dddbec;
#             color:  #000000;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow4_col5 {
#             background-color:  #c2cbe2;
#             color:  #000000;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow4_col6 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow4_col7 {
#             background-color:  #b1c2de;
#             color:  #000000;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow4_col8 {
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow5_col0 {
#             background-color:  #78abd0;
#             color:  #000000;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow5_col1 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow5_col2 {
#             background-color:  #056fae;
#             color:  #f1f1f1;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow5_col3 {
#             background-color:  #89b1d4;
#             color:  #000000;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow5_col4 {
#             background-color:  #d2d3e7;
#             color:  #000000;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow5_col5 {
#             background-color:  #c6cce3;
#             color:  #000000;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow5_col6 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow5_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow5_col8 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow6_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow6_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow6_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow6_col3 {
#             background-color:  #c2cbe2;
#             color:  #000000;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow6_col4 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_632b4f10_980f_11ea_a399_9c305b77d51erow6_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
# shap_test
# <style  type="text/css" >
#     #T_632e5dbe_980f_11ea_b922_9c305b77d51erow0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow0_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow0_col2 {
#             background-color:  #79abd0;
#             color:  #000000;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow0_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow0_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow0_col6 {
#             background-color:  #056ba7;
#             color:  #f1f1f1;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow0_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow0_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow1_col0 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow1_col1 {
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow1_col2 {
#             background-color:  #7bacd1;
#             color:  #000000;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow1_col3 {
#             background-color:  #4496c3;
#             color:  #000000;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow1_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow1_col5 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow1_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow1_col7 {
#             background-color:  #509ac6;
#             color:  #000000;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow1_col8 {
#             background-color:  #5a9ec9;
#             color:  #000000;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow2_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow2_col1 {
#             background-color:  #1379b5;
#             color:  #f1f1f1;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow2_col3 {
#             background-color:  #60a1ca;
#             color:  #000000;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow2_col4 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow2_col5 {
#             background-color:  #e4e1ef;
#             color:  #000000;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow2_col6 {
#             background-color:  #4c99c5;
#             color:  #000000;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow2_col7 {
#             background-color:  #549cc7;
#             color:  #000000;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow2_col8 {
#             background-color:  #e0deed;
#             color:  #000000;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow3_col0 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow3_col1 {
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow3_col2 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow3_col3 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow3_col4 {
#             background-color:  #dedcec;
#             color:  #000000;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow3_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow3_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow3_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow3_col8 {
#             background-color:  #3b92c1;
#             color:  #000000;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow4_col0 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow4_col1 {
#             background-color:  #197db7;
#             color:  #000000;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow4_col2 {
#             background-color:  #045585;
#             color:  #f1f1f1;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow4_col3 {
#             background-color:  #acc0dd;
#             color:  #000000;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow4_col4 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow4_col5 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow4_col6 {
#             background-color:  #549cc7;
#             color:  #000000;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow4_col7 {
#             background-color:  #045585;
#             color:  #f1f1f1;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow4_col8 {
#             background-color:  #2484ba;
#             color:  #000000;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow5_col0 {
#             background-color:  #dedcec;
#             color:  #000000;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow5_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow5_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow5_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow5_col4 {
#             background-color:  #e9e5f1;
#             color:  #000000;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow5_col5 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow5_col6 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow5_col7 {
#             background-color:  #dad9ea;
#             color:  #000000;
#         }    #T_632e5dbe_980f_11ea_b922_9c305b77d51erow5_col8 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_632e5dbe_980f_11ea_b922_9c305b77d51e" ><thead>    <tr>        <th class="index_name level0" >feature</th>        <th class="col_heading level0 col0" >atemp</th>        <th class="col_heading level0 col1" >datetime</th>        <th class="col_heading level0 col2" >holiday</th>        <th class="col_heading level0 col3" >humidity</th>        <th class="col_heading level0 col4" >season</th>        <th class="col_heading level0 col5" >temp</th>        <th class="col_heading level0 col6" >weather</th>        <th class="col_heading level0 col7" >windspeed</th>        <th class="col_heading level0 col8" >workingday</th>    </tr>    <tr>        <th class="index_name level0" >algo</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blan
# shap_train
# <style  type="text/css" >
#     #T_63347480_980f_11ea_aa76_9c305b77d51erow0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow0_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow0_col2 {
#             background-color:  #7dacd1;
#             color:  #000000;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow0_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow0_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow0_col6 {
#             background-color:  #4e9ac6;
#             color:  #000000;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow0_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow0_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow1_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow1_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow1_col2 {
#             background-color:  #86b0d3;
#             color:  #000000;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow1_col3 {
#             background-color:  #0872b1;
#             color:  #f1f1f1;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow1_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow1_col5 {
#             background-color:  #f4edf6;
#             color:  #000000;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow1_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow1_col7 {
#             background-color:  #6da6cd;
#             color:  #000000;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow1_col8 {
#             background-color:  #62a2cb;
#             color:  #000000;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow2_col0 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow2_col1 {
#             background-color:  #b5c4df;
#             color:  #000000;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow2_col2 {
#             background-color:  #046096;
#             color:  #f1f1f1;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow2_col3 {
#             background-color:  #cacee5;
#             color:  #000000;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow2_col4 {
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow2_col5 {
#             background-color:  #eee9f3;
#             color:  #000000;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow2_col6 {
#             background-color:  #e0dded;
#             color:  #000000;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow2_col7 {
#             background-color:  #b3c3de;
#             color:  #000000;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow2_col8 {
#             background-color:  #c2cbe2;
#             color:  #000000;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow3_col0 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow3_col1 {
#             background-color:  #afc1dd;
#             color:  #000000;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow3_col2 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow3_col3 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow3_col4 {
#             background-color:  #d3d4e7;
#             color:  #000000;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow3_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow3_col6 {
#             background-color:  #ebe6f2;
#             color:  #000000;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow3_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow3_col8 {
#             background-color:  #6fa7ce;
#             color:  #000000;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow4_col0 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow4_col1 {
#             background-color:  #cacee5;
#             color:  #000000;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow4_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow4_col3 {
#             background-color:  #a9bfdc;
#             color:  #000000;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow4_col4 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow4_col5 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow4_col6 {
#             background-color:  #d2d3e7;
#             color:  #000000;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow4_col7 {
#             background-color:  #045687;
#             color:  #f1f1f1;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow4_col8 {
#             background-color:  #549cc7;
#             color:  #000000;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow5_col0 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow5_col1 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow5_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow5_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow5_col4 {
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow5_col5 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow5_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow5_col7 {
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }    #T_63347480_980f_11ea_aa76_9c305b77d51erow5_col8 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_63347480_980f_11ea_aa76_9c305b77d51e" ><thead>    <tr>        <th class="index_name level0" >feature</th>        <th class="col_heading level0 col0" >atemp</th>        <th class="col_heading level0 col1" >datetime</th>        <th class="col_heading level0 col2" >holiday</th>        <th class="col_heading level0 col3" >humidity</th>        <th class="col_heading level0 col4" >season</th>        <th class="col_heading level0 col5" >temp</th>        <th class="col_heading level0 col6" >weather</th>        <th class="col_heading level0 col7" >windspeed</th>        <th class="col_heading level0 col8" >workingday</th>    </tr>    <tr>        <th class="index_name level0" >algo</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blan

# %%
rmse_dict = {}
for algo, path in paths.items():
    temp_results = []
    for path in glob(path +"*"):
        df = pd.read_csv(path)
        temp_results.append(df.loc[0, 'rmse'])
    rmse_dict[algo]  = temp_results

# %%
for k, v in rmse_dict.items():
    print(k, np.round(np.mean(v), 3), np.round(np.std(v), 3))
# Out:
# Lgbm 76.855 2.35
# Catboost 101.015 4.289
# Ours_kfold 83.697 2.615
# Ours_Vanilla 77.753 2.261
# Sklearn_Mean_Imputing 83.572 2.438
# Sklearn_One_Hot 89.655 2.582
# Xgboost_Mean_Imputing 83.7 2.181
# Xgboost_One_Hot 89.908 2.65

# %%
ntrees_dict = {}
for algo, path in paths.items():
    temp_results = []
    for path in glob(path +"*"):
        df = pd.read_csv(path)
        temp_results.append(df.loc[0, 'ntrees'])
    ntrees_dict[algo]  = temp_results
for k, v in ntrees_dict.items():
    print(k, np.round(np.mean(v), 3), np.round(np.std(v), 3))
# Out:
# Lgbm 100.0 0.0
# Catboost 100.0 0.0
# Ours_kfold 57.476 7.274
# Ours_Vanilla 100.0 0.0
# Sklearn_Mean_Imputing 100.0 0.0
# Sklearn_One_Hot 100.0 0.0
# Xgboost_Mean_Imputing 100.0 0.0
# Xgboost_One_Hot 100.0 0.0

# %%
nleaves_dict = {}
for algo, path in paths.items():
    temp_results = []
    for path in glob(path +"*"):
        df = pd.read_csv(path)
        temp_results.append(df.loc[0, 'nleaves'])
    nleaves_dict[algo]  = temp_results
for k, v in nleaves_dict.items():
    print(k, np.round(np.mean(v), 3), np.round(np.std(v), 3))
# Out:
# Lgbm 759.667 7.263
# Catboost 800.0 0.0
# Ours_kfold 427.048 47.758
# Ours_Vanilla 786.824 3.682
# Sklearn_Mean_Imputing 798.267 1.569
# Sklearn_One_Hot 799.667 0.471
# Xgboost_Mean_Imputing 792.962 3.777
# Xgboost_One_Hot 795.867 2.093
